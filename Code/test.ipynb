# %%
from greeter_allocation import *
from register_salesfloor_acclocation import *
from utils import transform_time_inout, create_working_flag, create_remaining_hours, alert_employee_shortage, convert_df_to_emp_view
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")

# %%
# 1. Read Emp Availability table, filter and format Time columns
path="../00_Input/01_Emp_Availability_Initial.xlsx" # TODO: Read from Frontend
df = pd.read_excel(path, names=['Name', 'Responsibility', 'Time in', 'Time out'])
filtered_df = df[~df['Responsibility'].isin(['Technology', 'Office Work']) & ~df['Name'].str.contains('Available')] # Filter out not-required roles and names
filtered_df= transform_time_inout(filtered_df)

# 2. Create Working Flag and Remaining Hours Left
work_status_df = create_working_flag(filtered_df)
work_status_df= work_status_df[work_status_df['Working Flag']==1] # Filter only working hours for every employee
work_status_df= create_remaining_hours(work_status_df, filtered_df)
work_status_df['Start_time'] = pd.to_datetime(work_status_df['Start_time'], format='%H:%M:%S').dt.time
work_status_df['End_time'] = pd.to_datetime(work_status_df['End_time'], format='%H:%M:%S').dt.time
# Out:
#  df.head()
#                     Name       Responsibility             Time in  \
# 0   Andrew (AJ) # Bowlen         Lead Student 2024-09-16 08:30:00
# 1  Analuisa Flores Teran  Sales Floor/Cashier 2024-09-16 08:45:00
# 5         Finn Broderick  Sales Floor/Cashier 2024-09-16 08:45:00
# 6          Ricardo Gomez  Sales Floor/Cashier 2024-09-16 08:45:00
# 8         Solymar Kneale  Sales Floor/Cashier 2024-09-16 08:45:00
#
#              Time out
# 0 2024-09-16 14:00:00
# 1 2024-09-16 11:00:00
# 5 2024-09-16 11:00:00
# 6 2024-09-16 12:00:00
# 8 2024-09-16 10:30:00
# Columns:
# Index(['Name', 'Responsibility', 'Time in', 'Time out'], dtype='object')
# First Row:
# Name              Andrew (AJ) # Bowlen
# Responsibility            Lead Student
# Time in            2024-09-16 08:30:00
# Time out           2024-09-16 14:00:00
# Name: 0, dtype: object
# Second Row:
# Name              Analuisa Flores Teran
# Responsibility      Sales Floor/Cashier
# Time in             2024-09-16 08:45:00
# Time out            2024-09-16 11:00:00
# Name: 1, dtype: object

# %%
#1. Read Shift Req table, format Time columns
emp_count_req= pd.read_excel('../00_Input/02_Emp_Count_Requirement.xlsx') # TODO: Read from Frontend
emp_count_req['From_Time'] = pd.to_datetime(emp_count_req['From_Time'], format='%H:%M:%S').dt.time
emp_count_req['To_Time'] = pd.to_datetime(emp_count_req['To_Time'], format='%H:%M:%S').dt.time

# 2. Alert if available employees are insufficient to satisfy the required count
emp_requirements= alert_employee_shortage(work_status_df, emp_count_req)
# Out:
# No shortage of employees for the whole day

# %%
greeter_assignment, greeter_shift_done_dict = allocate_greeter(work_status_df, emp_requirements)
# Out:
# Current Period: 07:30:00 to 08:00:00
# Current Period Data:
#  Empty DataFrame
# Columns: [Name, Start_time, End_time, Working Flag, Remaining_hours_left, Priority]
# Index: []
# Upstairs Greeters Assigned: []
# Downstairs Greeters Assigned: []
# -----------------------------------------------------------------------------
# Current Period: 08:00:00 to 08:30:00
# Current Period Data:
#  Empty DataFrame
# Columns: [Name, Start_time, End_time, Working Flag, Remaining_hours_left, Priority]
# Index: []
# Upstairs Greeters Assigned: []
# Downstairs Greeters Assigned: []
# -----------------------------------------------------------------------------
# Current Period: 08:30:00 to 09:00:00
# Current Period Data:
#                     Name Start_time  End_time  Working Flag  \
# 0  Andrew (AJ) # Bowlen   08:30:00  09:00:00             1
#
#    Remaining_hours_left  Priority
# 0                   5.5         1
# Upstairs Greeters Assigned: []
# Downstairs Greeters Assigned: []
# -----------------------------------------------------------------------------
# Current Period: 09:00:00 to 09:30:00
# Current Period Data:
#                        Name Start_time  End_time  Working Flag  \
# 1     Andrew (AJ) # Bowlen   09:00:00  09:30:00             1
# 21   Analuisa Flores Teran   09:00:00  09:30:00             1
# 41          Finn Broderick   09:00:00  09:30:00             1
# 61           Ricardo Gomez   09:00:00  09:30:00             1
# 81          Solymar Kneale   09:00:00  09:30:00             1
# 101            Carson Turk   09:00:00  09:30:00             1
# 121            Dev Mahajan   09:00:00  09:30:00             1
# 141           Ethan Palmer   09:00:00  09:30:00             1
#
#      Remaining_hours_left  Priority
# 1                     5.0         1
# 21                    2.0         1
# 41                    2.0         1
# 61                    3.0         1
# 81                    1.5         1
# 101                   4.0         1
# 121                   0.5         1
# 141                   3.0         1
# Upstairs Greeters Assigned: []
# Downstairs Greeters Assigned: []
# -----------------------------------------------------------------------------
# Current Period: 09:30:00 to 10:00:00
# Current Period Data:
#                        Name Start_time  End_time  Working Flag  \
# 2     Andrew (AJ) # Bowlen   09:30:00  10:00:00             1
# 22   Analuisa Flores Teran   09:30:00  10:00:00             1
# 42          Finn Broderick   09:30:00  10:00:00             1
# 62           Ricardo Gomez   09:30:00  10:00:00             1
# 82          Solymar Kneale   09:30:00  10:00:00             1
# 102            Carson Turk   09:30:00  10:00:00             1
# 142           Ethan Palmer   09:30:00  10:00:00             1
#
#      Remaining_hours_left  Priority
# 2                     4.5         1
# 22                    1.5         1
# 42                    1.5         1
# 62                    2.5         1
# 82                    1.0         1
# 102                   3.5         1
# 142                   2.5         1
# Upstairs Greeters Assigned: []
# Downstairs Greeters Assigned: []
# -----------------------------------------------------------------------------
# Current Period: 10:00:00 to 10:30:00
# Current Period Data:
#                        Name Start_time  End_time  Working Flag  \
# 3     Andrew (AJ) # Bowlen   10:00:00  10:30:00             1
# 23   Analuisa Flores Teran   10:00:00  10:30:00             1
# 43          Finn Broderick   10:00:00  10:30:00             1
# 63           Ricardo Gomez   10:00:00  10:30:00             1
# 83          Solymar Kneale   10:00:00  10:30:00             1
# 103            Carson Turk   10:00:00  10:30:00             1
# 143           Ethan Palmer   10:00:00  10:30:00             1
# 163          Ana* Gonzalez   10:00:00  10:30:00             1
# 183      Marsailles Wesley   10:00:00  10:30:00             1
#
#      Remaining_hours_left  Priority
# 3                     4.0         1
# 23                    1.0         1
# 43                    1.0         1
# 63                    2.0         1
# 83                    0.5         1
# 103                   3.0         1
# 143                   2.0         1
# 163                   1.0         1
# 183                   2.0         1
# Upstairs Greeters Assigned: ['Andrew (AJ) # Bowlen']
# Downstairs Greeters Assigned: ['Analuisa Flores Teran']
# -----------------------------------------------------------------------------
# Current Period: 10:30:00 to 11:00:00
# Current Period Data:
#                        Name Start_time  End_time  Working Flag  \
# 4     Andrew (AJ) # Bowlen   10:30:00  11:00:00             1
# 24   Analuisa Flores Teran   10:30:00  11:00:00             1
# 44          Finn Broderick   10:30:00  11:00:00             1
# 64           Ricardo Gomez   10:30:00  11:00:00             1
# 104            Carson Turk   10:30:00  11:00:00             1
# 144           Ethan Palmer   10:30:00  11:00:00             1
# 164          Ana* Gonzalez   10:30:00  11:00:00             1
# 184      Marsailles Wesley   10:30:00  11:00:00             1
# 204    Josiah Galvan-Lewis   10:30:00  11:00:00             1
# 224         Kaeden Stander   10:30:00  11:00:00             1
#
#      Remaining_hours_left  Priority
# 4                     3.5         2
# 24                    0.5         3
# 44                    0.5         1
# 64                    1.5         1
# 104                   2.5         1
# 144                   1.5         1
# 164                   0.5         1
# 184                   1.5         1
# 204                   5.5         1
# 224                   1.5         1
# Upstairs Greeters Assigned: ['Finn Broderick']
# Downstairs Greeters Assigned: ['Ricardo Gomez']
# -----------------------------------------------------------------------------
# Current Period: 11:00:00 to 11:30:00
# Current Period Data:
#                       Name Start_time  End_time  Working Flag  \
# 5    Andrew (AJ) # Bowlen   11:00:00  11:30:00             1
# 65          Ricardo Gomez   11:00:00  11:30:00             1
# 105           Carson Turk   11:00:00  11:30:00             1
# 145          Ethan Palmer   11:00:00  11:30:00             1
# 185     Marsailles Wesley   11:00:00  11:30:00             1
# 205   Josiah Galvan-Lewis   11:00:00  11:30:00             1
# 225        Kaeden Stander   11:00:00  11:30:00             1
# 245       Hanah # Wilkins   11:00:00  11:30:00             1
# 265        Kevin^ Jenkins   11:00:00  11:30:00             1
# 285            Luke* Ruhl   11:00:00  11:30:00             1
#
#      Remaining_hours_left  Priority
# 5                     3.0         2
# 65                    1.0         5
# 105                   2.0         1
# 145                   1.0         1
# 185                   1.0         1
# 205                   5.0         1
# 225                   1.0         1
# 245                   3.5         1
# 265                   3.0         1
# 285                   2.0         1
# Upstairs Greeters Assigned: ['Carson Turk']
# Downstairs Greeters Assigned: ['Ethan Palmer']
# -----------------------------------------------------------------------------
# Current Period: 11:30:00 to 12:00:00
# Current Period Data:
#                       Name Start_time  End_time  Working Flag  \
# 6    Andrew (AJ) # Bowlen   11:30:00  12:00:00             1
# 66          Ricardo Gomez   11:30:00  12:00:00             1
# 106           Carson Turk   11:30:00  12:00:00             1
# 146          Ethan Palmer   11:30:00  12:00:00             1
# 186     Marsailles Wesley   11:30:00  12:00:00             1
# 206   Josiah Galvan-Lewis   11:30:00  12:00:00             1
# 226        Kaeden Stander   11:30:00  12:00:00             1
# 246       Hanah # Wilkins   11:30:00  12:00:00             1
# 266        Kevin^ Jenkins   11:30:00  12:00:00             1
# 286            Luke* Ruhl   11:30:00  12:00:00             1
# 306       Joaquin Mendoza   11:30:00  12:00:00             1
# 326         Miguel Tanner   11:30:00  12:00:00             1
#
#      Remaining_hours_left  Priority
# 6                     2.5         2
# 66                    0.5         5
# 106                   1.5         6
# 146                   0.5         7
# 186                   0.5         1
# 206                   4.5         1
# 226                   0.5         1
# 246                   3.0         1
# 266                   2.5         1
# 286                   1.5         1
# 306                   1.5         1
# 326                   1.0         1
# Upstairs Greeters Assigned: ['Marsailles Wesley']
# Downstairs Greeters Assigned: ['Josiah Galvan-Lewis']
# -----------------------------------------------------------------------------
# Current Period: 12:00:00 to 12:30:00
# Current Period Data:
#                       Name Start_time  End_time  Working Flag  \
# 7    Andrew (AJ) # Bowlen   12:00:00  12:30:00             1
# 107           Carson Turk   12:00:00  12:30:00             1
# 207   Josiah Galvan-Lewis   12:00:00  12:30:00             1
# 247       Hanah # Wilkins   12:00:00  12:30:00             1
# 267        Kevin^ Jenkins   12:00:00  12:30:00             1
# 287            Luke* Ruhl   12:00:00  12:30:00             1
# 307       Joaquin Mendoza   12:00:00  12:30:00             1
# 327         Miguel Tanner   12:00:00  12:30:00             1
# 347         Elijah Kodjak   12:00:00  12:30:00             1
# 367         Lauren* Koski   12:00:00  12:30:00             1
#
#      Remaining_hours_left  Priority
# 7                     2.0         2
# 107                   1.0         6
# 207                   4.0         9
# 247                   2.5         1
# 267                   2.0         1
# 287                   1.0         1
# 307                   1.0         1
# 327                   0.5         1
# 347                   2.0         1
# 367                   1.0         1
# Upstairs Greeters Assigned: ['Hanah # Wilkins']
# Downstairs Greeters Assigned: ['Kevin^ Jenkins']
# -----------------------------------------------------------------------------
# Current Period: 12:30:00 to 13:00:00
# Current Period Data:
#                            Name Start_time  End_time  Working Flag  \
# 8         Andrew (AJ) # Bowlen   12:30:00  13:00:00             1
# 88              Solymar Kneale   12:30:00  13:00:00             1
# 108                Carson Turk   12:30:00  13:00:00             1
# 208        Josiah Galvan-Lewis   12:30:00  13:00:00             1
# 248            Hanah # Wilkins   12:30:00  13:00:00             1
# 268             Kevin^ Jenkins   12:30:00  13:00:00             1
# 288                 Luke* Ruhl   12:30:00  13:00:00             1
# 308            Joaquin Mendoza   12:30:00  13:00:00             1
# 348              Elijah Kodjak   12:30:00  13:00:00             1
# 368              Lauren* Koski   12:30:00  13:00:00             1
# 388           Cristian Andrade   12:30:00  13:00:00             1
# 408  Lulu (Lyndsey)* Arterburn   12:30:00  13:00:00             1
#
#      Remaining_hours_left  Priority
# 8                     1.5         2
# 88                    1.0         1
# 108                   0.5         6
# 208                   3.5         9
# 248                   2.0        10
# 268                   1.5        11
# 288                   0.5         1
# 308                   0.5         1
# 348                   1.5         1
# 368                   0.5         1
# 388                   2.5         1
# 408                   1.5         1
# Upstairs Greeters Assigned: ['Solymar Kneale']
# Downstairs Greeters Assigned: ['Luke* Ruhl']
# -----------------------------------------------------------------------------
# Current Period: 13:00:00 to 13:30:00
# Current Period Data:
#                            Name Start_time  End_time  Working Flag  \
# 9         Andrew (AJ) # Bowlen   13:00:00  13:30:00             1
# 89              Solymar Kneale   13:00:00  13:30:00             1
# 209        Josiah Galvan-Lewis   13:00:00  13:30:00             1
# 249            Hanah # Wilkins   13:00:00  13:30:00             1
# 269             Kevin^ Jenkins   13:00:00  13:30:00             1
# 349              Elijah Kodjak   13:00:00  13:30:00             1
# 389           Cristian Andrade   13:00:00  13:30:00             1
# 409  Lulu (Lyndsey)* Arterburn   13:00:00  13:30:00             1
# 429             AJ # Alkhamees   13:00:00  13:30:00             1
# 449            Joaquin Salinas   13:00:00  13:30:00             1
#
#      Remaining_hours_left  Priority
# 9                     1.0         2
# 89                    0.5        12
# 209                   3.0         9
# 249                   1.5        10
# 269                   1.0        11
# 349                   1.0         1
# 389                   2.0         1
# 409                   1.0         1
# 429                   1.0         1
# 449                   0.5         1
# Upstairs Greeters Assigned: ['Elijah Kodjak']
# Downstairs Greeters Assigned: ['Cristian Andrade']
# -----------------------------------------------------------------------------
# Current Period: 13:30:00 to 14:00:00
# Current Period Data:
#                            Name Start_time  End_time  Working Flag  \
# 10        Andrew (AJ) # Bowlen   13:30:00  14:00:00             1
# 170              Ana* Gonzalez   13:30:00  14:00:00             1
# 210        Josiah Galvan-Lewis   13:30:00  14:00:00             1
# 250            Hanah # Wilkins   13:30:00  14:00:00             1
# 270             Kevin^ Jenkins   13:30:00  14:00:00             1
# 350              Elijah Kodjak   13:30:00  14:00:00             1
# 390           Cristian Andrade   13:30:00  14:00:00             1
# 410  Lulu (Lyndsey)* Arterburn   13:30:00  14:00:00             1
# 430             AJ # Alkhamees   13:30:00  14:00:00             1
# 470             Cassidy Jacobs   13:30:00  14:00:00             1
# 490             Mariana Cepeda   13:30:00  14:00:00             1
# 510              Scott Hackney   13:30:00  14:00:00             1
# 530              Summer Sutton   13:30:00  14:00:00             1
#
#      Remaining_hours_left  Priority
# 10                    0.5         2
# 170                   2.5         1
# 210                   2.5         9
# 250                   1.0        10
# 270                   0.5        11
# 350                   0.5        14
# 390                   1.5        15
# 410                   0.5         1
# 430                   0.5         1
# 470                   4.5         1
# 490                   3.5         1
# 510                   3.0         1
# 530                   1.5         1
# Upstairs Greeters Assigned: ['Ana* Gonzalez']
# Downstairs Greeters Assigned: ['Lulu (Lyndsey)* Arterburn']
# -----------------------------------------------------------------------------
# Current Period: 14:00:00 to 14:30:00
# Current Period Data:
#                           Name Start_time  End_time  Working Flag  \
# 171             Ana* Gonzalez   14:00:00  14:30:00             1
# 211       Josiah Galvan-Lewis   14:00:00  14:30:00             1
# 251           Hanah # Wilkins   14:00:00  14:30:00             1
# 291                Luke* Ruhl   14:00:00  14:30:00             1
# 391          Cristian Andrade   14:00:00  14:30:00             1
# 471            Cassidy Jacobs   14:00:00  14:30:00             1
# 491            Mariana Cepeda   14:00:00  14:30:00             1
# 511             Scott Hackney   14:00:00  14:30:00             1
# 531             Summer Sutton   14:00:00  14:30:00             1
# 551          Anahi Guitierrez   14:00:00  14:30:00             1
# 571             Diego Navarro   14:00:00  14:30:00             1
# 591             Lohith Ramesh   14:00:00  14:30:00             1
# 611  Saaijeesh Sottalu Naresh   14:00:00  14:30:00             1
#
#      Remaining_hours_left  Priority
# 171                   2.0        16
# 211                   2.0         9
# 251                   0.5        10
# 291                   1.0        13
# 391                   1.0        15
# 471                   4.0         1
# 491                   3.0         1
# 511                   2.5         1
# 531                   1.0         1
# 551                   3.0         1
# 571                   3.0         1
# 591                   2.0         1
# 611                   2.0         1
# Upstairs Greeters Assigned: ['Cassidy Jacobs']
# Downstairs Greeters Assigned: ['Mariana Cepeda']
# -----------------------------------------------------------------------------
# Current Period: 14:30:00 to 15:00:00
# Current Period Data:
#                           Name Start_time  End_time  Working Flag  \
# 172             Ana* Gonzalez   14:30:00  15:00:00             1
# 212       Josiah Galvan-Lewis   14:30:00  15:00:00             1
# 292                Luke* Ruhl   14:30:00  15:00:00             1
# 392          Cristian Andrade   14:30:00  15:00:00             1
# 472            Cassidy Jacobs   14:30:00  15:00:00             1
# 492            Mariana Cepeda   14:30:00  15:00:00             1
# 512             Scott Hackney   14:30:00  15:00:00             1
# 532             Summer Sutton   14:30:00  15:00:00             1
# 552          Anahi Guitierrez   14:30:00  15:00:00             1
# 572             Diego Navarro   14:30:00  15:00:00             1
# 592             Lohith Ramesh   14:30:00  15:00:00             1
# 612  Saaijeesh Sottalu Naresh   14:30:00  15:00:00             1
# 632            Cassidy Sylves   14:30:00  15:00:00             1
#
#      Remaining_hours_left  Priority
# 172                   1.5        16
# 212                   1.5         9
# 292                   0.5        13
# 392                   0.5        15
# 472                   3.5        18
# 492                   2.5        19
# 512                   2.0         1
# 532                   0.5         1
# 552                   2.5         1
# 572                   2.5         1
# 592                   1.5         1
# 612                   1.5         1
# 632                   3.5         1
# Upstairs Greeters Assigned: ['Scott Hackney']
# Downstairs Greeters Assigned: ['Summer Sutton']
# -----------------------------------------------------------------------------
# Current Period: 15:00:00 to 15:30:00
# Current Period Data:
#                           Name Start_time  End_time  Working Flag  \
# 173             Ana* Gonzalez   15:00:00  15:30:00             1
# 213       Josiah Galvan-Lewis   15:00:00  15:30:00             1
# 313           Joaquin Mendoza   15:00:00  15:30:00             1
# 473            Cassidy Jacobs   15:00:00  15:30:00             1
# 493            Mariana Cepeda   15:00:00  15:30:00             1
# 513             Scott Hackney   15:00:00  15:30:00             1
# 553          Anahi Guitierrez   15:00:00  15:30:00             1
# 573             Diego Navarro   15:00:00  15:30:00             1
# 593             Lohith Ramesh   15:00:00  15:30:00             1
# 613  Saaijeesh Sottalu Naresh   15:00:00  15:30:00             1
# 633            Cassidy Sylves   15:00:00  15:30:00             1
# 653               Zadie Knapp   15:00:00  15:30:00             1
#
#      Remaining_hours_left  Priority
# 173                   1.0        16
# 213                   1.0         9
# 313                   1.0         1
# 473                   3.0        18
# 493                   2.0        19
# 513                   1.5        20
# 553                   2.0         1
# 573                   2.0         1
# 593                   1.0         1
# 613                   1.0         1
# 633                   3.0         1
# 653                   1.5         1
# Upstairs Greeters Assigned: ['Joaquin Mendoza']
# Downstairs Greeters Assigned: ['Anahi Guitierrez']
# -----------------------------------------------------------------------------
# Current Period: 15:30:00 to 16:00:00
# Current Period Data:
#                           Name Start_time  End_time  Working Flag  \
# 174             Ana* Gonzalez   15:30:00  16:00:00             1
# 214       Josiah Galvan-Lewis   15:30:00  16:00:00             1
# 314           Joaquin Mendoza   15:30:00  16:00:00             1
# 474            Cassidy Jacobs   15:30:00  16:00:00             1
# 494            Mariana Cepeda   15:30:00  16:00:00             1
# 514             Scott Hackney   15:30:00  16:00:00             1
# 554          Anahi Guitierrez   15:30:00  16:00:00             1
# 574             Diego Navarro   15:30:00  16:00:00             1
# 594             Lohith Ramesh   15:30:00  16:00:00             1
# 614  Saaijeesh Sottalu Naresh   15:30:00  16:00:00             1
# 634            Cassidy Sylves   15:30:00  16:00:00             1
# 654               Zadie Knapp   15:30:00  16:00:00             1
# 674           Serenity* Munoz   15:30:00  16:00:00             1
#
#      Remaining_hours_left  Priority
# 174                   0.5        16
# 214                   0.5         9
# 314                   0.5        22
# 474                   2.5        18
# 494                   1.5        19
# 514                   1.0        20
# 554                   1.5        23
# 574                   1.5         1
# 594                   0.5         1
# 614                   0.5         1
# 634                   2.5         1
# 654                   1.0         1
# 674                   2.5         1
# Upstairs Greeters Assigned: ['Diego Navarro']
# Downstairs Greeters Assigned: ['Lohith Ramesh']
# -----------------------------------------------------------------------------
# Current Period: 16:00:00 to 16:30:00
# Current Period Data:
#                    Name Start_time  End_time  Working Flag  \
# 475     Cassidy Jacobs   16:00:00  16:30:00             1
# 495     Mariana Cepeda   16:00:00  16:30:00             1
# 515      Scott Hackney   16:00:00  16:30:00             1
# 555   Anahi Guitierrez   16:00:00  16:30:00             1
# 575      Diego Navarro   16:00:00  16:30:00             1
# 635     Cassidy Sylves   16:00:00  16:30:00             1
# 655        Zadie Knapp   16:00:00  16:30:00             1
# 675    Serenity* Munoz   16:00:00  16:30:00             1
# 695    Elizabeth Jurry   16:00:00  16:30:00             1
# 715  Madelyn* Ozdarski   16:00:00  16:30:00             1
# 735       Naman Talwar   16:00:00  16:30:00             1
#
#      Remaining_hours_left  Priority
# 475                   2.0        18
# 495                   1.0        19
# 515                   0.5        20
# 555                   1.0        23
# 575                   1.0        24
# 635                   2.0         1
# 655                   0.5         1
# 675                   2.0         1
# 695                   2.0         1
# 715                   2.0         1
# 735                   2.0         1
# Upstairs Greeters Assigned: ['Cassidy Sylves']
# Downstairs Greeters Assigned: ['Zadie Knapp']
# -----------------------------------------------------------------------------
# Current Period: 16:30:00 to 17:00:00
# Current Period Data:
#                    Name Start_time  End_time  Working Flag  \
# 476     Cassidy Jacobs   16:30:00  17:00:00             1
# 496     Mariana Cepeda   16:30:00  17:00:00             1
# 556   Anahi Guitierrez   16:30:00  17:00:00             1
# 576      Diego Navarro   16:30:00  17:00:00             1
# 636     Cassidy Sylves   16:30:00  17:00:00             1
# 676    Serenity* Munoz   16:30:00  17:00:00             1
# 696    Elizabeth Jurry   16:30:00  17:00:00             1
# 716  Madelyn* Ozdarski   16:30:00  17:00:00             1
# 736       Naman Talwar   16:30:00  17:00:00             1
#
#      Remaining_hours_left  Priority
# 476                   1.5        18
# 496                   0.5        19
# 556                   0.5        23
# 576                   0.5        24
# 636                   1.5        26
# 676                   1.5         1
# 696                   1.5         1
# 716                   1.5         1
# 736                   1.5         1
# Upstairs Greeters Assigned: ['Serenity* Munoz']
# Downstairs Greeters Assigned: ['Elizabeth Jurry']
# -----------------------------------------------------------------------------
# Current Period: 17:00:00 to 17:30:00
# Current Period Data:
#                            Name Start_time  End_time  Working Flag  \
# 417  Lulu (Lyndsey)* Arterburn   17:00:00  17:30:00             1
# 477             Cassidy Jacobs   17:00:00  17:30:00             1
# 617   Saaijeesh Sottalu Naresh   17:00:00  17:30:00             1
# 637             Cassidy Sylves   17:00:00  17:30:00             1
# 677            Serenity* Munoz   17:00:00  17:30:00             1
# 697            Elizabeth Jurry   17:00:00  17:30:00             1
# 717          Madelyn* Ozdarski   17:00:00  17:30:00             1
# 737               Naman Talwar   17:00:00  17:30:00             1
# 757            Aaron* Dorrance   17:00:00  17:30:00             1
# 777              Calvin # Levy   17:00:00  17:30:00             1
# 797                Ellia* Bono   17:00:00  17:30:00             1
# 817             Kayhaan Rashiq   17:00:00  17:30:00             1
# 837                Mali Chavez   17:00:00  17:30:00             1
#
#      Remaining_hours_left  Priority
# 417                   1.0        17
# 477                   1.0        18
# 617                   1.0         1
# 637                   1.0        26
# 677                   1.0        28
# 697                   1.0        29
# 717                   1.0         1
# 737                   1.0         1
# 757                   1.0         1
# 777                   1.0         1
# 797                   1.0         1
# 817                   1.0         1
# 837                   1.5         1
# Upstairs Greeters Assigned: ['Saaijeesh Sottalu Naresh']
# Downstairs Greeters Assigned: ['Madelyn* Ozdarski']
# -----------------------------------------------------------------------------
# Current Period: 17:30:00 to 18:00:00
# Current Period Data:
#                            Name Start_time  End_time  Working Flag  \
# 418  Lulu (Lyndsey)* Arterburn   17:30:00  18:00:00             1
# 478             Cassidy Jacobs   17:30:00  18:00:00             1
# 618   Saaijeesh Sottalu Naresh   17:30:00  18:00:00             1
# 638             Cassidy Sylves   17:30:00  18:00:00             1
# 678            Serenity* Munoz   17:30:00  18:00:00             1
# 698            Elizabeth Jurry   17:30:00  18:00:00             1
# 718          Madelyn* Ozdarski   17:30:00  18:00:00             1
# 738               Naman Talwar   17:30:00  18:00:00             1
# 758            Aaron* Dorrance   17:30:00  18:00:00             1
# 778              Calvin # Levy   17:30:00  18:00:00             1
# 798                Ellia* Bono   17:30:00  18:00:00             1
# 818             Kayhaan Rashiq   17:30:00  18:00:00             1
# 838                Mali Chavez   17:30:00  18:00:00             1
#
#      Remaining_hours_left  Priority
# 418                   0.5        17
# 478                   0.5        18
# 618                   0.5        30
# 638                   0.5        26
# 678                   0.5        28
# 698                   0.5        29
# 718                   0.5        31
# 738                   0.5         1
# 758                   0.5         1
# 778                   0.5         1
# 798                   0.5         1
# 818                   0.5         1
# 838                   1.0         1
# Upstairs Greeters Assigned: ['Naman Talwar']
# Downstairs Greeters Assigned: ['Aaron* Dorrance']
# -----------------------------------------------------------------------------
# Current Period: 18:00:00 to 18:30:00
# Current Period Data:
#              Name Start_time  End_time  Working Flag  Remaining_hours_left  \
# 839  Mali Chavez   18:00:00  18:30:00             1                   0.5
#
#      Priority
# 839         1
# Upstairs Greeters Assigned: []
# Downstairs Greeters Assigned: []
# -----------------------------------------------------------------------------
# Current Period: 18:30:00 to 19:00:00
# Current Period Data:
#  Empty DataFrame
# Columns: [Name, Start_time, End_time, Working Flag, Remaining_hours_left, Priority]
# Index: []
# Upstairs Greeters Assigned: []
# Downstairs Greeters Assigned: []
# -----------------------------------------------------------------------------
# Current Period: 19:00:00 to 19:30:00
# Current Period Data:
#  Empty DataFrame
# Columns: [Name, Start_time, End_time, Working Flag, Remaining_hours_left, Priority]
# Index: []
# Upstairs Greeters Assigned: []
# Downstairs Greeters Assigned: []
# -----------------------------------------------------------------------------

# %%
register_allocation= allocate_register_salesfloor(emp_requirements, work_status_df, greeter_assignment)
final_allocation= pd.merge(greeter_assignment, register_allocation, how='outer', left_on=['From_Time', 'To_Time'], right_on=['From_Time', 'To_Time'])
# Out:
# ---------------------------------------------------------------------------------------------
# Allocating registers between 07:30:00 to 08:00:00 ...
# No Registers Needed
# ---------------------------------------------------------------------------------------------
# Allocating registers between 08:00:00 to 08:30:00 ...
# No Registers Needed
# ---------------------------------------------------------------------------------------------
# Allocating registers between 08:30:00 to 09:00:00 ...
# No Registers Needed
# ---------------------------------------------------------------------------------------------
# Allocating registers between 09:00:00 to 09:30:00 ...
# Total # Emp Working: 8
# Total Emp Working: ['Andrew (AJ) # Bowlen', 'Analuisa Flores Teran', 'Finn Broderick', 'Ricardo Gomez', 'Solymar Kneale', 'Carson Turk', 'Dev Mahajan', 'Ethan Palmer']
# Greeters Count: 0
# Current Greeters: []
# RU_retained_count 0
# RD_retained_count 0
# retained_RUs []
# retained_RDs []
# new_RU_needed_count 2
# new_RD_needed_count 2
# new_RU_assigned ['Andrew (AJ) # Bowlen', 'Carson Turk']
# new_RD_assigned ['Ricardo Gomez', 'Ethan Palmer']
# unassigned_count 4
# salesfloor_up_assigned_count 2
# salesfloor_up_assigned ['Analuisa Flores Teran', 'Finn Broderick']
# salesfloor_dwn_assigned_count 2
# salesfloor_dwn_assigned ['Solymar Kneale', 'Dev Mahajan']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 09:30:00 to 10:00:00 ...
# Total # Emp Working: 7
# Total Emp Working: ['Andrew (AJ) # Bowlen', 'Analuisa Flores Teran', 'Finn Broderick', 'Ricardo Gomez', 'Solymar Kneale', 'Carson Turk', 'Ethan Palmer']
# Greeters Count: 0
# Current Greeters: []
# RU_retained_count 2
# RD_retained_count 2
# retained_RUs ['Andrew (AJ) # Bowlen', 'Carson Turk']
# retained_RDs ['Ricardo Gomez', 'Ethan Palmer']
# new_RU_needed_count 0
# new_RD_needed_count 0
# new_RU_assigned []
# new_RD_assigned []
# unassigned_count 3
# salesfloor_up_assigned_count 1
# salesfloor_up_assigned ['Analuisa Flores Teran', 'Finn Broderick']
# salesfloor_dwn_assigned_count 2
# salesfloor_dwn_assigned ['Solymar Kneale']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 10:00:00 to 10:30:00 ...
# Total # Emp Working: 9
# Total Emp Working: ['Andrew (AJ) # Bowlen', 'Analuisa Flores Teran', 'Finn Broderick', 'Ricardo Gomez', 'Solymar Kneale', 'Carson Turk', 'Ethan Palmer', 'Ana* Gonzalez', 'Marsailles Wesley']
# Greeters Count: 2
# Current Greeters: ['Andrew (AJ) # Bowlen', 'Analuisa Flores Teran']
# RU_retained_count 1
# RD_retained_count 2
# retained_RUs ['Carson Turk']
# retained_RDs ['Ricardo Gomez', 'Ethan Palmer']
# new_RU_needed_count 1
# new_RD_needed_count 0
# new_RU_assigned ['Marsailles Wesley']
# new_RD_assigned []
# unassigned_count 3
# salesfloor_up_assigned_count 1
# salesfloor_up_assigned ['Finn Broderick']
# salesfloor_dwn_assigned_count 2
# salesfloor_dwn_assigned ['Solymar Kneale', 'Ana* Gonzalez']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 10:30:00 to 11:00:00 ...
# Total # Emp Working: 10
# Total Emp Working: ['Andrew (AJ) # Bowlen', 'Analuisa Flores Teran', 'Finn Broderick', 'Ricardo Gomez', 'Carson Turk', 'Ethan Palmer', 'Ana* Gonzalez', 'Marsailles Wesley', 'Josiah Galvan-Lewis', 'Kaeden Stander']
# Greeters Count: 2
# Current Greeters: ['Finn Broderick', 'Ricardo Gomez']
# RU_retained_count 2
# RD_retained_count 1
# retained_RUs ['Carson Turk', 'Marsailles Wesley']
# retained_RDs ['Ethan Palmer']
# new_RU_needed_count 0
# new_RD_needed_count 1
# new_RU_assigned []
# new_RD_assigned ['Josiah Galvan-Lewis']
# unassigned_count 4
# salesfloor_up_assigned_count 2
# salesfloor_up_assigned ['Andrew (AJ) # Bowlen', 'Kaeden Stander']
# salesfloor_dwn_assigned_count 2
# salesfloor_dwn_assigned ['Ana* Gonzalez', 'Analuisa Flores Teran']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 11:00:00 to 11:30:00 ...
# Total # Emp Working: 10
# Total Emp Working: ['Andrew (AJ) # Bowlen', 'Ricardo Gomez', 'Carson Turk', 'Ethan Palmer', 'Marsailles Wesley', 'Josiah Galvan-Lewis', 'Kaeden Stander', 'Hanah # Wilkins', 'Kevin^ Jenkins', 'Luke* Ruhl']
# Greeters Count: 2
# Current Greeters: ['Carson Turk', 'Ethan Palmer']
# RU_retained_count 1
# RD_retained_count 1
# retained_RUs ['Marsailles Wesley']
# retained_RDs ['Josiah Galvan-Lewis']
# new_RU_needed_count 1
# new_RD_needed_count 1
# new_RU_assigned ['Hanah # Wilkins']
# new_RD_assigned ['Andrew (AJ) # Bowlen']
# unassigned_count 4
# salesfloor_up_assigned_count 2
# salesfloor_up_assigned ['Kaeden Stander', 'Kevin^ Jenkins']
# salesfloor_dwn_assigned_count 2
# salesfloor_dwn_assigned ['Luke* Ruhl', 'Ricardo Gomez']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 11:30:00 to 12:00:00 ...
# Total # Emp Working: 12
# Total Emp Working: ['Andrew (AJ) # Bowlen', 'Ricardo Gomez', 'Carson Turk', 'Ethan Palmer', 'Marsailles Wesley', 'Josiah Galvan-Lewis', 'Kaeden Stander', 'Hanah # Wilkins', 'Kevin^ Jenkins', 'Luke* Ruhl', 'Joaquin Mendoza', 'Miguel Tanner']
# Greeters Count: 2
# Current Greeters: ['Marsailles Wesley', 'Josiah Galvan-Lewis']
# RU_retained_count 1
# RD_retained_count 1
# retained_RUs ['Hanah # Wilkins']
# retained_RDs ['Andrew (AJ) # Bowlen']
# new_RU_needed_count 1
# new_RD_needed_count 1
# new_RU_assigned ['Kevin^ Jenkins']
# new_RD_assigned ['Carson Turk']
# unassigned_count 6
# salesfloor_up_assigned_count 3
# salesfloor_up_assigned ['Kaeden Stander', 'Joaquin Mendoza', 'Miguel Tanner']
# salesfloor_dwn_assigned_count 3
# salesfloor_dwn_assigned ['Luke* Ruhl', 'Ricardo Gomez', 'Ethan Palmer']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 12:00:00 to 12:30:00 ...
# Total # Emp Working: 10
# Total Emp Working: ['Andrew (AJ) # Bowlen', 'Carson Turk', 'Josiah Galvan-Lewis', 'Hanah # Wilkins', 'Kevin^ Jenkins', 'Luke* Ruhl', 'Joaquin Mendoza', 'Miguel Tanner', 'Elijah Kodjak', 'Lauren* Koski']
# Greeters Count: 2
# Current Greeters: ['Hanah # Wilkins', 'Kevin^ Jenkins']
# RU_retained_count 0
# RD_retained_count 2
# retained_RUs []
# retained_RDs ['Andrew (AJ) # Bowlen', 'Carson Turk']
# new_RU_needed_count 2
# new_RD_needed_count 0
# new_RU_assigned ['Josiah Galvan-Lewis', 'Elijah Kodjak']
# new_RD_assigned []
# unassigned_count 4
# salesfloor_up_assigned_count 2
# salesfloor_up_assigned ['Joaquin Mendoza', 'Miguel Tanner']
# salesfloor_dwn_assigned_count 2
# salesfloor_dwn_assigned ['Luke* Ruhl', 'Lauren* Koski']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 12:30:00 to 13:00:00 ...
# Total # Emp Working: 12
# Total Emp Working: ['Andrew (AJ) # Bowlen', 'Solymar Kneale', 'Carson Turk', 'Josiah Galvan-Lewis', 'Hanah # Wilkins', 'Kevin^ Jenkins', 'Luke* Ruhl', 'Joaquin Mendoza', 'Elijah Kodjak', 'Lauren* Koski', 'Cristian Andrade', 'Lulu (Lyndsey)* Arterburn']
# Greeters Count: 2
# Current Greeters: ['Solymar Kneale', 'Luke* Ruhl']
# RU_retained_count 2
# RD_retained_count 2
# retained_RUs ['Josiah Galvan-Lewis', 'Elijah Kodjak']
# retained_RDs ['Andrew (AJ) # Bowlen', 'Carson Turk']
# new_RU_needed_count 0
# new_RD_needed_count 0
# new_RU_assigned []
# new_RD_assigned []
# unassigned_count 6
# salesfloor_up_assigned_count 3
# salesfloor_up_assigned ['Joaquin Mendoza', 'Cristian Andrade', 'Hanah # Wilkins']
# salesfloor_dwn_assigned_count 3
# salesfloor_dwn_assigned ['Lauren* Koski', 'Kevin^ Jenkins', 'Lulu (Lyndsey)* Arterburn']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 13:00:00 to 13:30:00 ...
# Total # Emp Working: 10
# Total Emp Working: ['Andrew (AJ) # Bowlen', 'Solymar Kneale', 'Josiah Galvan-Lewis', 'Hanah # Wilkins', 'Kevin^ Jenkins', 'Elijah Kodjak', 'Cristian Andrade', 'Lulu (Lyndsey)* Arterburn', 'AJ # Alkhamees', 'Joaquin Salinas']
# Greeters Count: 2
# Current Greeters: ['Elijah Kodjak', 'Cristian Andrade']
# RU_retained_count 1
# RD_retained_count 1
# retained_RUs ['Josiah Galvan-Lewis']
# retained_RDs ['Andrew (AJ) # Bowlen']
# new_RU_needed_count 1
# new_RD_needed_count 1
# new_RU_assigned ['Hanah # Wilkins']
# new_RD_assigned ['Kevin^ Jenkins']
# unassigned_count 4
# salesfloor_up_assigned_count 2
# salesfloor_up_assigned ['AJ # Alkhamees', 'Solymar Kneale']
# salesfloor_dwn_assigned_count 2
# salesfloor_dwn_assigned ['Lulu (Lyndsey)* Arterburn', 'Joaquin Salinas']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 13:30:00 to 14:00:00 ...
# Total # Emp Working: 13
# Total Emp Working: ['Andrew (AJ) # Bowlen', 'Ana* Gonzalez', 'Josiah Galvan-Lewis', 'Hanah # Wilkins', 'Kevin^ Jenkins', 'Elijah Kodjak', 'Cristian Andrade', 'Lulu (Lyndsey)* Arterburn', 'AJ # Alkhamees', 'Cassidy Jacobs', 'Mariana Cepeda', 'Scott Hackney', 'Summer Sutton']
# Greeters Count: 2
# Current Greeters: ['Ana* Gonzalez', 'Lulu (Lyndsey)* Arterburn']
# RU_retained_count 2
# RD_retained_count 2
# retained_RUs ['Josiah Galvan-Lewis', 'Hanah # Wilkins']
# retained_RDs ['Andrew (AJ) # Bowlen', 'Kevin^ Jenkins']
# new_RU_needed_count 0
# new_RD_needed_count 0
# new_RU_assigned []
# new_RD_assigned []
# unassigned_count 7
# salesfloor_up_assigned_count 3
# salesfloor_up_assigned ['AJ # Alkhamees', 'Cassidy Jacobs', 'Mariana Cepeda']
# salesfloor_dwn_assigned_count 4
# salesfloor_dwn_assigned ['Scott Hackney', 'Cristian Andrade', 'Summer Sutton', 'Elijah Kodjak']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 14:00:00 to 14:30:00 ...
# Total # Emp Working: 13
# Total Emp Working: ['Ana* Gonzalez', 'Josiah Galvan-Lewis', 'Hanah # Wilkins', 'Luke* Ruhl', 'Cristian Andrade', 'Cassidy Jacobs', 'Mariana Cepeda', 'Scott Hackney', 'Summer Sutton', 'Anahi Guitierrez', 'Diego Navarro', 'Lohith Ramesh', 'Saaijeesh Sottalu Naresh']
# Greeters Count: 2
# Current Greeters: ['Cassidy Jacobs', 'Mariana Cepeda']
# RU_retained_count 2
# RD_retained_count 0
# retained_RUs ['Josiah Galvan-Lewis', 'Hanah # Wilkins']
# retained_RDs []
# new_RU_needed_count 0
# new_RD_needed_count 2
# new_RU_assigned []
# new_RD_assigned ['Anahi Guitierrez', 'Diego Navarro']
# unassigned_count 7
# salesfloor_up_assigned_count 3
# salesfloor_up_assigned ['Ana* Gonzalez', 'Lohith Ramesh', 'Saaijeesh Sottalu Naresh']
# salesfloor_dwn_assigned_count 4
# salesfloor_dwn_assigned ['Scott Hackney', 'Cristian Andrade', 'Summer Sutton', 'Luke* Ruhl']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 14:30:00 to 15:00:00 ...
# Total # Emp Working: 13
# Total Emp Working: ['Ana* Gonzalez', 'Josiah Galvan-Lewis', 'Luke* Ruhl', 'Cristian Andrade', 'Cassidy Jacobs', 'Mariana Cepeda', 'Scott Hackney', 'Summer Sutton', 'Anahi Guitierrez', 'Diego Navarro', 'Lohith Ramesh', 'Saaijeesh Sottalu Naresh', 'Cassidy Sylves']
# Greeters Count: 2
# Current Greeters: ['Scott Hackney', 'Summer Sutton']
# RU_retained_count 1
# RD_retained_count 2
# retained_RUs ['Josiah Galvan-Lewis']
# retained_RDs ['Anahi Guitierrez', 'Diego Navarro']
# new_RU_needed_count 1
# new_RD_needed_count 0
# new_RU_assigned ['Cassidy Jacobs']
# new_RD_assigned []
# unassigned_count 7
# salesfloor_up_assigned_count 3
# salesfloor_up_assigned ['Ana* Gonzalez', 'Lohith Ramesh', 'Saaijeesh Sottalu Naresh']
# salesfloor_dwn_assigned_count 4
# salesfloor_dwn_assigned ['Luke* Ruhl', 'Cristian Andrade', 'Cassidy Sylves', 'Mariana Cepeda']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 15:00:00 to 15:30:00 ...
# Total # Emp Working: 12
# Total Emp Working: ['Ana* Gonzalez', 'Josiah Galvan-Lewis', 'Joaquin Mendoza', 'Cassidy Jacobs', 'Mariana Cepeda', 'Scott Hackney', 'Anahi Guitierrez', 'Diego Navarro', 'Lohith Ramesh', 'Saaijeesh Sottalu Naresh', 'Cassidy Sylves', 'Zadie Knapp']
# Greeters Count: 2
# Current Greeters: ['Joaquin Mendoza', 'Anahi Guitierrez']
# RU_retained_count 2
# RD_retained_count 1
# retained_RUs ['Josiah Galvan-Lewis', 'Cassidy Jacobs']
# retained_RDs ['Diego Navarro']
# new_RU_needed_count 0
# new_RD_needed_count 1
# new_RU_assigned []
# new_RD_assigned ['Cassidy Sylves']
# unassigned_count 6
# salesfloor_up_assigned_count 3
# salesfloor_up_assigned ['Ana* Gonzalez', 'Lohith Ramesh', 'Saaijeesh Sottalu Naresh']
# salesfloor_dwn_assigned_count 3
# salesfloor_dwn_assigned ['Mariana Cepeda', 'Scott Hackney', 'Zadie Knapp']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 15:30:00 to 16:00:00 ...
# Total # Emp Working: 13
# Total Emp Working: ['Ana* Gonzalez', 'Josiah Galvan-Lewis', 'Joaquin Mendoza', 'Cassidy Jacobs', 'Mariana Cepeda', 'Scott Hackney', 'Anahi Guitierrez', 'Diego Navarro', 'Lohith Ramesh', 'Saaijeesh Sottalu Naresh', 'Cassidy Sylves', 'Zadie Knapp', 'Serenity* Munoz']
# Greeters Count: 2
# Current Greeters: ['Diego Navarro', 'Lohith Ramesh']
# RU_retained_count 2
# RD_retained_count 1
# retained_RUs ['Josiah Galvan-Lewis', 'Cassidy Jacobs']
# retained_RDs ['Cassidy Sylves']
# new_RU_needed_count 0
# new_RD_needed_count 1
# new_RU_assigned []
# new_RD_assigned ['Serenity* Munoz']
# unassigned_count 7
# salesfloor_up_assigned_count 3
# salesfloor_up_assigned ['Ana* Gonzalez', 'Saaijeesh Sottalu Naresh', 'Anahi Guitierrez']
# salesfloor_dwn_assigned_count 4
# salesfloor_dwn_assigned ['Mariana Cepeda', 'Scott Hackney', 'Zadie Knapp', 'Joaquin Mendoza']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 16:00:00 to 16:30:00 ...
# Total # Emp Working: 11
# Total Emp Working: ['Cassidy Jacobs', 'Mariana Cepeda', 'Scott Hackney', 'Anahi Guitierrez', 'Diego Navarro', 'Cassidy Sylves', 'Zadie Knapp', 'Serenity* Munoz', 'Elizabeth Jurry', 'Madelyn* Ozdarski', 'Naman Talwar']
# Greeters Count: 2
# Current Greeters: ['Cassidy Sylves', 'Zadie Knapp']
# RU_retained_count 1
# RD_retained_count 1
# retained_RUs ['Cassidy Jacobs']
# retained_RDs ['Serenity* Munoz']
# new_RU_needed_count 1
# new_RD_needed_count 1
# new_RU_assigned ['Elizabeth Jurry']
# new_RD_assigned ['Madelyn* Ozdarski']
# unassigned_count 5
# salesfloor_up_assigned_count 2
# salesfloor_up_assigned ['Anahi Guitierrez', 'Naman Talwar']
# salesfloor_dwn_assigned_count 3
# salesfloor_dwn_assigned ['Mariana Cepeda', 'Scott Hackney', 'Diego Navarro']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 16:30:00 to 17:00:00 ...
# Total # Emp Working: 9
# Total Emp Working: ['Cassidy Jacobs', 'Mariana Cepeda', 'Anahi Guitierrez', 'Diego Navarro', 'Cassidy Sylves', 'Serenity* Munoz', 'Elizabeth Jurry', 'Madelyn* Ozdarski', 'Naman Talwar']
# Greeters Count: 2
# Current Greeters: ['Serenity* Munoz', 'Elizabeth Jurry']
# RU_retained_count 1
# RD_retained_count 1
# retained_RUs ['Cassidy Jacobs']
# retained_RDs ['Madelyn* Ozdarski']
# new_RU_needed_count 1
# new_RD_needed_count 1
# new_RU_assigned ['Cassidy Sylves']
# new_RD_assigned ['Naman Talwar']
# unassigned_count 3
# salesfloor_up_assigned_count 1
# salesfloor_up_assigned ['Anahi Guitierrez']
# salesfloor_dwn_assigned_count 2
# salesfloor_dwn_assigned ['Mariana Cepeda', 'Diego Navarro']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 17:00:00 to 17:30:00 ...
# Total # Emp Working: 13
# Total Emp Working: ['Lulu (Lyndsey)* Arterburn', 'Cassidy Jacobs', 'Saaijeesh Sottalu Naresh', 'Cassidy Sylves', 'Serenity* Munoz', 'Elizabeth Jurry', 'Madelyn* Ozdarski', 'Naman Talwar', 'Aaron* Dorrance', 'Calvin # Levy', 'Ellia* Bono', 'Kayhaan Rashiq', 'Mali Chavez']
# Greeters Count: 2
# Current Greeters: ['Saaijeesh Sottalu Naresh', 'Madelyn* Ozdarski']
# RU_retained_count 2
# RD_retained_count 1
# retained_RUs ['Cassidy Jacobs', 'Cassidy Sylves']
# retained_RDs ['Naman Talwar']
# new_RU_needed_count 0
# new_RD_needed_count 1
# new_RU_assigned []
# new_RD_assigned ['Mali Chavez']
# unassigned_count 7
# salesfloor_up_assigned_count 3
# salesfloor_up_assigned ['Lulu (Lyndsey)* Arterburn', 'Serenity* Munoz', 'Elizabeth Jurry']
# salesfloor_dwn_assigned_count 4
# salesfloor_dwn_assigned ['Aaron* Dorrance', 'Calvin # Levy', 'Ellia* Bono', 'Kayhaan Rashiq']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 17:30:00 to 18:00:00 ...
# Total # Emp Working: 13
# Total Emp Working: ['Lulu (Lyndsey)* Arterburn', 'Cassidy Jacobs', 'Saaijeesh Sottalu Naresh', 'Cassidy Sylves', 'Serenity* Munoz', 'Elizabeth Jurry', 'Madelyn* Ozdarski', 'Naman Talwar', 'Aaron* Dorrance', 'Calvin # Levy', 'Ellia* Bono', 'Kayhaan Rashiq', 'Mali Chavez']
# Greeters Count: 2
# Current Greeters: ['Naman Talwar', 'Aaron* Dorrance']
# RU_retained_count 2
# RD_retained_count 1
# retained_RUs ['Cassidy Jacobs', 'Cassidy Sylves']
# retained_RDs ['Mali Chavez']
# new_RU_needed_count 0
# new_RD_needed_count 1
# new_RU_assigned []
# new_RD_assigned ['Lulu (Lyndsey)* Arterburn']
# unassigned_count 7
# salesfloor_up_assigned_count 3
# salesfloor_up_assigned ['Serenity* Munoz', 'Elizabeth Jurry', 'Saaijeesh Sottalu Naresh']
# salesfloor_dwn_assigned_count 4
# salesfloor_dwn_assigned ['Calvin # Levy', 'Ellia* Bono', 'Kayhaan Rashiq', 'Madelyn* Ozdarski']
# ---------------------------------------------------------------------------------------------
# Allocating registers between 18:00:00 to 18:30:00 ...
# No Registers Needed
# ---------------------------------------------------------------------------------------------
# Allocating registers between 18:30:00 to 19:00:00 ...
# No Registers Needed

# %%
# Get the final employee view
emp_view= convert_df_to_emp_view(final_allocation)

# Format time
final_allocation["From_Time"] = final_allocation["From_Time"].dt.strftime("%I:%M %p")
final_allocation["To_Time"] = final_allocation["To_Time"].dt.strftime("%I:%M %p")
final_allocation.drop(columns=['Greeter_Down_Needed', 'Greeter_Up_Needed', 'Reg_Up_Needed', 'Reg_Down_Needed'], inplace=True)
# Out:
# Data sorting and formating Successfull

# %%
# Get the current date and time
current_datetime = datetime.now()
current_datetime = current_datetime.strftime("%Y-%m-%d-%H-%M-%S")

# Save for flask output
final_allocation.to_excel(r"..\01_Output\Final_Allocation.xlsx", index=False)
emp_view.to_excel(r"..\01_Output\Final_Allocation_Emp_View.xlsx", index=False)

final_allocation.to_excel(fr"..\01_Output\Historical_Files\Final_Allocation_{current_datetime}.xlsx", index=False)
emp_view.to_excel(fr"..\01_Output\Historical_Files\Final_Allocation_Emp_View_{current_datetime}.xlsx", index=False)
